# %% [markdown]
# <a href="https://colab.research.google.com/github/afdifznsyh/POSTEST-1-DATAMINING/blob/main/A2_2109116024_POSTTEST_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <h1>Posttest Praktikum Data Mining</h1>
#
# NIM **2109116024**
#
# NAMA **AFDILLAH FAUZIANSYAH**
#
# > Kerjakanlah tugas berikut berdasarkan instruksi yang diberkan. Kumpulkanlah hasil posttest ini pada Github dengan mengumpulkan link repository kalian.
#
# Ketentuan pengumpulan tugas :
# 1. Kumpul Tugas ini dengan Format Kelas_NIM_Posttest 1.ipynb
# 2. Kumpulkan dalam bentuk link repository github
# 3. Berikan penjelasan untuk setiap blok kode dengan membuat text atau comment pada kodingan
# 4. Untuk bagian penjelasan gausa terlalu panjang.
# singkat padat dan jelas

# %%
import pandas as pd
#Untuk mengimport package pandas
import seaborn as sns
#Untuk mengimport package seaborn
import plotly.express as px
#Untuk mengimport package plotly
df = pd.read_csv("ChurnBank.csv")
df #df.info untuk memanggil dataset ChurnBank.csv
# Out:
#     Unnamed: 0  CLIENTNUM     Attrition_Flag  Customer_Age Gender  \
# 0         6036  720010608  Attrited Customer            37      M
# 1         6684  711323283  Attrited Customer            57      M
# 2         4272  794707083  Attrited Customer            50      M
# 3         9759  709657533  Attrited Customer            44      M
# 4         4740  716625033  Attrited Customer            32      F
# 5         9597  715076358  Attrited Customer            57      M
# 6         5009  804829533  Attrited Customer            59      M
# 7         8200  712144158  Attrited Customer            53      F
# 8         5016  795599883  Attrited Customer            57      F
# 9         8350  709222008  Attrited Customer            41      M
# 10        8139  809844108  Existing Customer            48      M
# 11         176  716264358  Existing Customer            53      M
# 12        8020  778163508  Existing Customer            37      F
# ...

# %% [markdown]
# ## Business Understanding ##
#
# Perusahaan bank kita adalah perusahaan yang bekerja dibidang layanan jasa keuangan seperti menyimpan uang, transfer uang antar bank dll. Tujuan dari perusahaan kita adalah untuk memberikan layanan keuangan dengan mengarah sektor masyarakat berbagai lapisan agar bisa memakai layanan kita serta kita juga menampilkan dataset Bank dan kartu kredit klien kita untuk menampilkan data mengelola keuangan pengguna dengan menggunakan algoritma naive bayes untuk menampilkan data pengguna dengan lebih menarik, mudah dipahami dan mendetail.

# %% [markdown]
# ## Data Understanding

# %%
filter = df.Attrition_Flag == "Attrited Customer"
df1 = df[filter] 
#df.info df1 adalah dataset yang berisi Attrited Customer
df2 = df[~filter] 
#df.info df2 adalah dataset yang berisikan selain Attrited Customer
df3 = df[df.Customer_Age < 50] 
#df.info df3 adalah dataset yang berisikan customer dengan usia kurang dari 50 tahun
df4 = df[df.Marital_Status == "Single"] 
#df.info df4 adalah dataset yang berisikan customer yang Marital_Status Single

# %%
df1 #Memanggil dataset dari df1 diatas\
# Out:
#    Unnamed: 0  CLIENTNUM     Attrition_Flag  Customer_Age Gender  \
# 0        6036  720010608  Attrited Customer            37      M
# 1        6684  711323283  Attrited Customer            57      M
# 2        4272  794707083  Attrited Customer            50      M
# 3        9759  709657533  Attrited Customer            44      M
# 4        4740  716625033  Attrited Customer            32      F
# 5        9597  715076358  Attrited Customer            57      M
# 6        5009  804829533  Attrited Customer            59      M
# 7        8200  712144158  Attrited Customer            53      F
# 8        5016  795599883  Attrited Customer            57      F
# 9        8350  709222008  Attrited Customer            41      M
#
#   Education_Level Marital_Status Income_Category Card_Category  Credit_Limit
# 0         Unknown         Single     $40K - $60K          Blue       10226.0
# 1      Uneducated        Married     $60K - $80K          Blue        2527.0
# ...

# %%
df2
# Out:
#     Unnamed: 0  CLIENTNUM     Attrition_Flag  Customer_Age Gender  \
# 10        8139  809844108  Existing Customer            48      M
# 11         176  716264358  Existing Customer            53      M
# 12        8020  778163508  Existing Customer            37      F
# 13         357  711857733  Existing Customer            49      M
# 14        6562  720070383  Existing Customer            41      F
# 15        4563  809809008  Existing Customer            47      F
# 16       10084  718161708  Existing Customer            46      F
# 17        5725  771079833  Existing Customer            40      F
# 18        2587  711639708  Existing Customer            42      M
# 19        8226  713700258  Existing Customer            55      F
#
#    Education_Level Marital_Status Income_Category Card_Category  Credit_Limit
# 10       Doctorate         Single     $60K - $80K          Blue        8086.0
# 11      Uneducated        Married    $80K - $120K          Blue       26792.0
# ...

# %%
df3
# Out:
#     Unnamed: 0  CLIENTNUM     Attrition_Flag  Customer_Age Gender  \
# 0         6036  720010608  Attrited Customer            37      M
# 3         9759  709657533  Attrited Customer            44      M
# 4         4740  716625033  Attrited Customer            32      F
# 9         8350  709222008  Attrited Customer            41      M
# 10        8139  809844108  Existing Customer            48      M
# 12        8020  778163508  Existing Customer            37      F
# 13         357  711857733  Existing Customer            49      M
# 14        6562  720070383  Existing Customer            41      F
# 15        4563  809809008  Existing Customer            47      F
# 16       10084  718161708  Existing Customer            46      F
# 17        5725  771079833  Existing Customer            40      F
# 18        2587  711639708  Existing Customer            42      M
#
#    Education_Level Marital_Status Income_Category Card_Category  Credit_Limit
# ...

# %%
df4
# Out:
#     Unnamed: 0  CLIENTNUM     Attrition_Flag  Customer_Age Gender  \
# 0         6036  720010608  Attrited Customer            37      M
# 2         4272  794707083  Attrited Customer            50      M
# 4         4740  716625033  Attrited Customer            32      F
# 6         5009  804829533  Attrited Customer            59      M
# 7         8200  712144158  Attrited Customer            53      F
# 9         8350  709222008  Attrited Customer            41      M
# 10        8139  809844108  Existing Customer            48      M
# 13         357  711857733  Existing Customer            49      M
# 14        6562  720070383  Existing Customer            41      F
# 17        5725  771079833  Existing Customer            40      F
# 18        2587  711639708  Existing Customer            42      M
#
#    Education_Level Marital_Status Income_Category Card_Category  Credit_Limit
# 0          Unknown         Single     $40K - $60K          Blue       10226.0
# ...

# %%
dfi = (df.info())
dfi
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       20 non-null     int64
#  1   CLIENTNUM        20 non-null     int64
#  2   Attrition_Flag   20 non-null     object
#  3   Customer_Age     20 non-null     int64
#  4   Gender           20 non-null     object
#  5   Education_Level  20 non-null     object
#  6   Marital_Status   20 non-null     object
#  7   Income_Category  20 non-null     object
#  8   Card_Category    20 non-null     object
#  9   Credit_Limit     20 non-null     float64
# dtypes: float64(1), int64(3), object(6)
# memory usage: 1.7+ KB

# %% [markdown]
# <p>Dari data info yang ada maka :</p>

# %%
dfm = df.aggregate({"Unnamed: 0":["min", "max", "mean", "std"],
                    "CLIENTNUM":["min", "max", "mean", "std"],
                     "Customer_Age":["min", "max", "mean", "std"],
                     "Credit_Limit":["min", "max", "mean", "std"]})
#nilai rata-rata, max ,min dan standar deviasi untuk kolom yang bertipe angka
dfm
# Out:
#         Unnamed: 0     CLIENTNUM  Customer_Age  Credit_Limit
# min     176.000000  7.092220e+08     32.000000   1438.300000
# max   10084.000000  8.098441e+08     59.000000  26792.000000
# mean   6105.100000  7.424893e+08     47.250000   8114.580000
# std    2850.304026  4.045524e+07      7.859791   8331.036819

# %% [markdown]
# ## Explore Data ##

# %% [markdown]
# ### Comparasion (Perbandingan)

# %%
sns.countplot(data=df, x="Attrition_Flag")
#Menampilkan data dengan diagram batang yang attired customer dan bukan attired customer
# Out:
# <AxesSubplot:xlabel='Attrition_Flag', ylabel='count'>

# %%
 sns.countplot(data=df, x="Education_Level")
#menampilkan macam-macam Education level berdasarkan kategori-kategorinya
# Out:
# <AxesSubplot:xlabel='Education_Level', ylabel='count'>

# %%
sns.countplot(data=df, x="Education_Level", hue="Gender")
#Menampilkan macam-macam Education level berdasarkan gendernya
# Out:
# <AxesSubplot:xlabel='Education_Level', ylabel='count'>

# %% [markdown]
# ### Distribution (Distribusi)

# %%
sns.histplot(data=df, x="Credit_Limit")
#historgram dan boxplot credit card limit
# Out:
# <AxesSubplot:xlabel='Credit_Limit', ylabel='Count'>

# %%
sns.boxplot(data=df, x="Credit_Limit")
# Out:
# <AxesSubplot:xlabel='Credit_Limit'>

# %%
sns.histplot(data=df, x="Customer_Age")
#histogram dan boxplot Customer_Age
# Out:
# <AxesSubplot:xlabel='Customer_Age', ylabel='Count'>

# %%
sns.boxplot(data=df, x="Customer_Age")
# Out:
# <AxesSubplot:xlabel='Customer_Age'>

# %% [markdown]
# ### Relation (Relasi)

# %%
sns.scatterplot(data=df, x="Customer_Age", y="Credit_Limit")
#SCATTERPLOT untuk customer_Age dan credit card limit
# Out:
# <AxesSubplot:xlabel='Customer_Age', ylabel='Credit_Limit'>

# %% [markdown]
# ### Composition (Komposisi)

# %%
px.pie(df, names="Income_Category")
#pieplot untuk Income Category
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
px.pie(df, names="Education_Level")
#pieplot untuk Education Level
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### Boxplot

# %%
sns.boxplot(data=df, x="Credit_Limit", y="Gender")
#Credit Card Limit dengan Gender sebagai pemisahnya
# Out:
# <AxesSubplot:xlabel='Credit_Limit', ylabel='Gender'>

# %%
sns.boxplot(data=df, x="Credit_Limit", y="Attrition_Flag")
#Credit Card Limit dengan Attrition_Flag sebagai pemisahnya
# Out:
# <AxesSubplot:xlabel='Credit_Limit', ylabel='Attrition_Flag'>

# %%
sns.boxplot(data=df, x="Customer_Age", y="Attrition_Flag")
#Age dengan Attrition_Flag sebagai pemisahnya
# Out:
# <AxesSubplot:xlabel='Customer_Age', ylabel='Attrition_Flag'>

# %% [markdown]
# ### Countplot

# %%
sns.countplot(data=df, x="Attrition_Flag", hue="Gender")
#Attrition_Flag dengan Gender sebagai pemisahnya
# Out:
# <AxesSubplot:xlabel='Attrition_Flag', ylabel='count'>

# %% [markdown]
# ### Heatmap

# %%
dfnum = df[['Unnamed: 0', 'CLIENTNUM', 'Customer_Age', 'Credit_Limit']]
sns.heatmap(data=dfnum)
dfnum
# Out:
#     Unnamed: 0  CLIENTNUM  Customer_Age  Credit_Limit
# 0         6036  720010608            37       10226.0
# 1         6684  711323283            57        2527.0
# 2         4272  794707083            50        3495.0
# 3         9759  709657533            44        7793.0
# 4         4740  716625033            32        2761.0
# 5         9597  715076358            57       23714.0
# 6         5009  804829533            59       24621.0
# 7         8200  712144158            53        2370.0
# 8         5016  795599883            57        2404.0
# 9         8350  709222008            41        4742.0
# 10        8139  809844108            48        8086.0
# 11         176  716264358            53       26792.0
# 12        8020  778163508            37        5245.0
# 13         357  711857733            49       18584.0
# 14        6562  720070383            41        2429.0
# 15        4563  809809008            47        3111.0
# ...

# %% [markdown]
# ## Algoritma Naive Bayes

# %%
#hapus kolom Unnamed: 0, CLIENTNUM, Umur, dan Limit Kartu Kredit (initinya yang berupa primary key dan bukan tipe kategori)
#disimpan di df baru

# Buatlah sebuah fungsi naive bayes dengan ketentuan
# Mengambil data dari dataframe yang telah diproses pada blok sebelumnya (diatas)
# Nama fungsinya adalah naive_bayes
# Mengambil 1 saja parameter yaitu sebuah list berisi kategori

# Outputnya berupa prediksi Attrited Customer atau Existing Customer
# Outputnya berupa tuple (_hasilnya, persentasenya berapa) contoh (Existing Customer, 0.004)

# Tidak boleh menggunakan library manapun selain pandas dan numpy
# contoh
# def naive_bayes(prediksi:list)-> tuple :
#   ........

# jadi nanti saat saya coba masukan data 
# naive_bayes(["F",	"Uneducated","Single", "Unknown	Blue"]) akan keluar tuple berupa ("Attired Customer", 0.002)

# %%
dfn = df.drop(['Unnamed: 0', 'CLIENTNUM', 'Customer_Age', 'Credit_Limit'], axis=1)
dfn

def naivebayes(kemungkinan:list):
  ac = dfn[dfn.Attrition_Flag == 'Attrited Customer'] 
  #dataset khusus Attrited Customer
  kasus_ac = len(ac)/len(dfn) 
  #peluang kasus Attrited Customer

  ex = dfn[dfn.Attrition_Flag == 'Existing Customer'] 
  #dataset khusus Existing Customer
  kasus_ex = len(ex)/len(dfn) 
  #peluang kasus Existing Customer

  #Hitung nilai P(XK|Ci) untuk setiap kelas i
  for i in range(len(kemungkinan)):
    p_ac = ac[ac.iloc[:,i] == kemungkinan[i]]
    #Variabel kemungkinan Attrited Customer dengan mengambil index location/iloc dari index kolom dataset AC
    p_ex = ex[ex.iloc[:,i] == kemungkinan[i]]
    #Variabel kemungkinan Attrited Customer dengan mengambil index location/iloc dari index kolom dataset EX

    #Jumlah total setiap kasus 
    a = len(ac) + len(dfn.iloc[:,i].unique())
    b = len(ex) + len(dfn.iloc[:,i].unique())

    peluang_baru_ac = (len(p_ac) +1) / a
    peluang_baru_ex = (len(p_ex) +1) / b

  #Hitung nilai P(X|Ci) untuk setiap Kelas (Label)
    if i == 0: #jika nilainya nol, maka akan tetap nol.
      p_terjadi_ac = peluang_baru_ac
      p_terjadi_ex = peluang_baru_ex
    else: #jika tidak, maka dapat dikalikan 
      p_terjadi_ac *= peluang_baru_ac
      p_terjadi_ex *= peluang_baru_ex

  #Hitung nilai P(X|Ci) * P(Ci)
  peluang_baru_ac = kasus_ac * p_terjadi_ac
  peluang_baru_ex = kasus_ex * p_terjadi_ex

  #Menetukan klas dari kasus
  total_p = peluang_baru_ac + peluang_baru_ex
  perbandingan = peluang_baru_ex / total_p
  output = 'Attrited Customer' if perbandingan < 0.5 else 'Existing Customer'
  turn = str(perbandingan)
  print('Hasil perhitungan akhir adalah ' + output + ' dengan nilai peluang ' + turn)

naivebayes(["F", "Uneducated", "Single", "Unknown", "Blue"])
naivebayes(["M", "Graduate", "Single", "Less than $40K", "Blue"])
# Out:
# Hasil perhitungan akhir adalah Attrited Customer dengan nilai peluang 0.25
# Hasil perhitungan akhir adalah Existing Customer dengan nilai peluang 0.5
